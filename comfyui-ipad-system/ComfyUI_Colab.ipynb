# %% [markdown]
# # ?? ComfyUI ??? Google Colab
#
# ## ? ???? ?????? ?????? ?????
#
# **????????:**
# - ? GPU ????? ?? Google (T4)
# - ? ????? ?????? ????
# - ? ????? ??????? ????????
# - ? ????? ?????
# - ? ???? ??? ?????? ?? iPad
#
# ---
#
# ## ?? ?????????:
#
# 1. **???? ???? ??????? ????????**
# 2. **????? ??? ????? ???????** (~5 ?????)
# 3. **???? ??????** ???? ?????
# 4. **???? ???????!** ??
#
# ---

# %% [markdown]
# ## 1?? ?????? ?? GPU

# %%
import locale
locale.getpreferredencoding = lambda: "UTF-8"

# !nvidia-smi
print("\n? GPU ????!")

# %% [markdown]
# ## 2?? ????? ComfyUI

# %%
# %%capture
# ????? ????

import os
os.chdir('/content')

# ??????? ComfyUI
# !git clone https://github.com/comfyanonymous/ComfyUI.git
os.chdir('/content/ComfyUI')

# ????? ?????????
# !pip install -r requirements.txt
# !pip install xformers

print("? ?? ????? ComfyUI")

# %%
print("? ????? ????? ComfyUI ?????!")

# %% [markdown]
# ## 3?? ????? ??????? ????????

# %%
import os
os.chdir('/content/ComfyUI')

print("?? ???? ????? ???????...")
print("? ?? ?????? ??? 3-5 ?????\n")

# ????? Stable Diffusion v1.5
print("1??  ????? Stable Diffusion v1.5 (4GB)...")
# !wget -q --show-progress -O models/checkpoints/v1-5-pruned-emaonly.safetensors \
  "https://huggingface.co/runwayml/stable-diffusion-v1-5/resolve/main/v1-5-pruned-emaonly.safetensors"

print("\n2??  ????? VAE (320MB)...")
# !wget -q --show-progress -O models/vae/vae-ft-mse-840000-ema-pruned.safetensors \
  "https://huggingface.co/stabilityai/sd-vae-ft-mse-original/resolve/main/vae-ft-mse-840000-ema-pruned.safetensors"

print("\n3??  ????? AnimateDiff (1.7GB)...")
# !wget -q --show-progress -O models/animatediff_models/mm_sd_v15_v2.ckpt \
  "https://huggingface.co/guoyww/animatediff/resolve/main/mm_sd_v15_v2.ckpt"

print("\n??????????????????????????????")
print("? ????? ????? ???? ???????!")
print("??????????????????????????????")

# %% [markdown]
# ## 4?? ??? ComfyUI ?? ???? ???

# %%
import subprocess
import threading
import time
import socket
import urllib.request

def iframe_thread(port):
    while True:
        time.sleep(0.5)
        sock = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
        result = sock.connect_ex(('127.0.0.1', port))
        if result == 0:
            break
        sock.close()
    print("\n?????????????????????????????????????????")
    print("? ComfyUI ???? ????!")
    print("?????????????????????????????????????????")
    print("\n?? ???? ?????? ?????:")

# ????? cloudflared ?????? ?????
# !wget -q https://github.com/cloudflare/cloudflared/releases/latest/download/cloudflared-linux-amd64.deb
# !dpkg -i cloudflared-linux-amd64.deb

print("?? ???? ??? ComfyUI...")
print("? ????? ????...\n")

# ??? ComfyUI
# !nohup python main.py --listen 0.0.0.0 --port 8188 > /tmp/comfyui.log 2>&1 &

# ??? cloudflare tunnel
# !nohup cloudflared tunnel --url http://localhost:8188 > /tmp/tunnel.log 2>&1 &

# ?????? ?????
threading.Thread(target=iframe_thread, daemon=True, args=(8188,)).start()
time.sleep(10)

# ??? ??????
# !grep -o 'https://[^ ]*trycloudflare.com' /tmp/tunnel.log | head -1

print("\n?? ????? ??? ?????? ??:")
print("   - ?????????")
print("   - iPad")
print("   - ??????")
print("   - ?? ????!")
print("\n?? ???? ?????? - ????? ???? 12 ????")
print("\n?????????????????????????????????????????")

# %% [markdown]
# ## ?? ????? ?????? ??????? (???????)

# %%
# %%html
# <div style="background: linear-gradient(135deg, #667eea 0%, #764ba2 100%); padding: 30px; border-radius: 15px; color: white; font-family: Arial;">
#   <h2 style="text-align: center; margin-bottom: 20px;">?? ???? ?????? ???????</h2>
#
#   <div style="background: rgba(255,255,255,0.95); padding: 20px; border-radius: 10px; color: #333; margin-bottom: 15px;">
#     <h3>? ????? Prompts ?????:</h3>
#     <ul>
#       <li><strong>????? ??????:</strong> beautiful sunset over mountains, cinematic lighting, 8k</li>
#       <li><strong>???????:</strong> professional portrait, studio lighting, detailed face, photorealistic</li>
#       <li><strong>?? ????:</strong> digital art, vibrant colors, trending on artstation, detailed</li>
#       <li><strong>????:</strong> anime style, beautiful character, detailed eyes, high quality</li>
#     </ul>
#   </div>
#
#   <div style="background: rgba(255,255,255,0.95); padding: 20px; border-radius: 10px; color: #333;">
#     <h3>?? Negative Prompts ?????? ???:</h3>
#     <p style="background: #f0f0f0; padding: 10px; border-radius: 5px; font-family: monospace;">
#       ugly, deformed, low quality, blurry, watermark, text, cropped, worst quality, bad anatomy
#     </p>
#   </div>
# </div>

# %% [markdown]
# ## ??? ????? ?????

# %%
# ??? ??????? GPU
# !nvidia-smi

# %%
# ??? ??????? ??? ???? ?????
# !tail -50 /tmp/comfyui.log

# %%
# ????? ??? ??????
print("?? ?????? ?????:")
# !grep -o 'https://[^ ]*trycloudflare.com' /tmp/tunnel.log | head -1

# %% [markdown]
# ---
#
# ## ?? ????? ?????????
#
# ### ?????? ??? ???? ???????:
#
# 1. **?????? Prompts ???????:**
#    - ????? ??: "cat"
#    - ??????: "beautiful cat, detailed fur, studio lighting, 8k, masterpiece"
#
# 2. **?????? Negative Prompts ??????:**
#    - ???? ?????? ???? ????
#    - ????? ????????
#
# 3. **????????? ?????? ???:**
#    - Steps: 20-30
#    - CFG Scale: 7-8
#    - Size: 512x512 (??????) ?? 768x768
#
# 4. **??????:**
#    - GPU T4: ~30 ????? ?????? 512x512
#    - ???? **?????** ?? CPU!
#
# ### ?? ??????? ????:
#
# - ? **Google Colab ????? ?? 12 ????**
# - ?? **??????? ??????** ??? ?????? ??????
# - ?? **???? ??????** ??? ???????!
# - ?? **????? ????? ???????** ?? ?? ???
#
# ---
#
# ## ?? ????? ??????
#
# - [ComfyUI Examples](https://comfyanonymous.github.io/ComfyUI_examples/)
# - [Stable Diffusion Prompting Guide](https://stable-diffusion-art.com/prompt-guide/)
# - [CivitAI Models](https://civitai.com/)
#
# ---
#
# <div style="text-align: center; padding: 20px; background: #f0f0f0; border-radius: 10px; margin-top: 20px;">
#   <h2>?? ?????? ????????!</h2>
#   <p style="color: #666; font-size: 14px;">???? ?? ?? ?? ??? ???????? ?????</p>
# </div>
